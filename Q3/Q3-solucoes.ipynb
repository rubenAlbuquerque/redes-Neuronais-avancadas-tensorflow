# %% [markdown]
# # In-Class Quiz Nº 3

# %% [markdown]
# <hr style="border:1px  solid black"> </hr>

# %% [markdown]
# ### (Fill in)
# ## Name:
# ## Number:

# %% [markdown]
# <hr style="border:1px  solid black"> </hr>

# %% [markdown]
# ## Develop and run the requested code in the cells immediately below the questions.

# %% [markdown]
# # IMPORTANTE:
# ## Once completed, save this Jupyter notebook with the following name:
# ## Axxxxx-Q3.ipynb (Axxxxx: student number)
# ##  and then upload the file to the Moodle link provided for that purpose.

# %% [markdown]
# <hr style="border:2px solid black"> </hr>

# %% [markdown]
# # Data: kMNIST dataset (small version) - pickle file $\texttt{kMNISTsmall.p}$
# ## This file has the following variables (in a dictionary)
# * ### X1: training data ($10000\times(28\times28)$  uint8 array)
# * ### y1: classes of the training data (10 japanese characters, class-numbers 0 to 9)
# * ### X2: test data ($5000\times(28\times28)$ uint8 array)
# * ### y2: classes of the test data (10 japanese characters, class-numbers 0 to 9)

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import tensorflow.keras as keras
from sklearn.metrics import confusion_matrix, roc_curve

import pickle
from time import time

#load data
D=pickle.load(open('kMNISTsmall.p','rb'))
D=pickle.load(open('../Q2/quiz/kMNISTsmall.p','rb'))
                #    kMNISTlarge.p','rb'))
X1=D.X1
X2=D.X2
y1=D.y1
y2=D.y2

# %%
print('X1:',X1.shape,X1.dtype)
print('y1:',y1.shape)
print('X2:',X2.shape)
print('y2:',y2.shape)
# Out:
# X1: (10000, 28, 28) uint8
# y1: (10000,)
# X2: (5000, 28, 28)
# y2: (5000,)

# %%
pickle.dump(D,open('kMNISTsmall.p','wb'))

# %%
# plt.figure(figsize=(15,15))
# c=1
# for i in range(10):
#     for j in range(10):
#         plt.subplot(10,10,c)
#         c+=1
#         plt.imshow(A[i*10+j,:],cmap='binary')
#         plt.axis('off')

# %% [markdown]
# # Question 1:
# ##  Consider an MLP network with the following architecture:
# ##  - an input layer able to deal with the kMNIST images.
# ##  - 3 hidden layers with 50 units each and with $\texttt{ReLu}$ activations.
# ##  - an output layer with 10 units and a softmax activation function
# ### a) Build this network, and compile it with the loss and the optimizer of your choice. Make sure not to include any extra layers (e.g. Dropout). Print the total number of parameters of the MLP.
# ### b) Train the network for 100 epochs with a batch-size of 5000. Use the kMNIST training set. For this purpose use the raw data (make sure not to perform any scaling or transformation of the  data). Also include the test data as the validation set during training.
# ### c) On the same figure, plot the curve of the losses and the accuracies for the training and validation sets during the training process.  Comment the results.
# ### d) Print the total number of errors and the confusion matrix for the test dataset.

# %% [markdown]
# ## 1.a)

# %%
#build the MLP
mlp=keras.Sequential()
mlp.add(keras.layers.Dense(50,activation='relu',input_shape=(784,)))
mlp.add(keras.layers.Dense(50,activation='relu'))
mlp.add(keras.layers.Dense(50,activation='relu'))
mlp.add(keras.layers.Dense(10,activation='softmax'))
print(mlp.summary())

#compile the network
mlp.compile(optimizer='nadam',loss='categorical_crossentropy',metrics=['accuracy'])
# Out:
# Model: "sequential_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_28 (Dense)             (None, 50)                39250
# _________________________________________________________________
# dense_29 (Dense)             (None, 50)                2550
# _________________________________________________________________
# dense_30 (Dense)             (None, 50)                2550
# _________________________________________________________________
# dense_31 (Dense)             (None, 10)                510
# =================================================================
# Total params: 44,860
# Trainable params: 44,860
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# ## 1.b)

# %%
#prepare data + labels
X1=X1.reshape((10000,784))*1.#/255.
X2=X2.reshape((5000,784))*1.#/255.
Y1=keras.utils.to_categorical(y1)
Y2=keras.utils.to_categorical(y2)
print(X1.shape,X2.shape,Y1.shape,Y2.shape)

train=mlp.fit(X1,Y1,epochs=100,batch_size=5000,validation_data=(X2,Y2))
# Out:
# (10000, 784) (5000, 784) (10000, 10) (5000, 10)
# Epoch 1/100
# 2/2 [==============================] - 1s 192ms/step - loss: 92.9722 - accuracy: 0.0954 - val_loss: 53.5968 - val_accuracy: 0.1208
# Epoch 2/100
# 2/2 [==============================] - 0s 67ms/step - loss: 49.9684 - accuracy: 0.1240 - val_loss: 37.8700 - val_accuracy: 0.1392
# Epoch 3/100
# 2/2 [==============================] - 0s 71ms/step - loss: 34.3361 - accuracy: 0.1629 - val_loss: 28.6698 - val_accuracy: 0.1656
# Epoch 4/100
# 2/2 [==============================] - 0s 112ms/step - loss: 25.0647 - accuracy: 0.2091 - val_loss: 22.7799 - val_accuracy: 0.1872
# Epoch 5/100
# 2/2 [==============================] - 0s 80ms/step - loss: 19.1432 - accuracy: 0.2357 - val_loss: 18.5235 - val_accuracy: 0.2020
# Epoch 6/100
# 2/2 [==============================] - 0s 75ms/step - loss: 15.1181 - accuracy: 0.2642 - val_loss: 15.6204 - val_accuracy: 0.2188
# Epoch 7/100
# 2/2 [==============================] - 0s 68ms/step - loss: 12.3297 - accuracy: 0.2946 - val_loss: 13.5000 - val_accuracy: 0.2372
# Epoch 8/100
# 2/2 [==============================] - 0s 76ms/step - loss: 10.3152 - accuracy: 0.3278 - val_loss: 11.8678 - val_accuracy: 0.2598
# Epoch 9/100
# 2/2 [==============================] - 0s 70ms/step - loss: 8.7899 - accuracy: 0.3559 - val_loss: 10.7123 - val_accuracy: 0.2718
# Epoch 10/100
# 2/2 [==============================] - 0s 74ms/step - loss: 7.6762 - accuracy: 0.3764 - val_loss: 9.6529 - val_accuracy: 0.2856
# Epoch 11/100
# 2/2 [==============================] - 0s 69ms/step - loss: 6.7412 - accuracy: 0.3997 - val_loss: 8.7650 - val_accuracy: 0.2966
# Epoch 12/100
# 2/2 [==============================] - 0s 73ms/step - loss: 6.0449 - accuracy: 0.4188 - val_loss: 8.0629 - val_accuracy: 0.3064
# Epoch 13/100
# 2/2 [==============================] - 0s 72ms/step - loss: 5.4571 - accuracy: 0.4329 - val_loss: 7.5056 - val_accuracy: 0.3206
# Epoch 14/100
# 2/2 [==============================] - 0s 79ms/step - loss: 4.9690 - accuracy: 0.4507 - val_loss: 6.9956 - val_accuracy: 0.3324
# Epoch 15/100
# 2/2 [==============================] - 0s 78ms/step - loss: 4.5777 - accuracy: 0.4645 - val_loss: 6.5846 - val_accuracy: 0.3360
# Epoch 16/100
# 2/2 [==============================] - 0s 76ms/step - loss: 4.2414 - accuracy: 0.4771 - val_loss: 6.2355 - val_accuracy: 0.3438
# Epoch 17/100
# 2/2 [==============================] - 0s 63ms/step - loss: 3.9470 - accuracy: 0.4930 - val_loss: 5.9548 - val_accuracy: 0.3494
# Epoch 18/100
# 2/2 [==============================] - 0s 63ms/step - loss: 3.6888 - accuracy: 0.5020 - val_loss: 5.6584 - val_accuracy: 0.3574
100
# 2/2 [==============================] - 0s 66ms/step - loss: 0.7943 - accuracy: 0.7739 - val_loss: 2.6264 - val_accuracy: 0.4960
# Epoch 89/100
# 2/2 [==============================] - 0s 79ms/step - loss: 0.7927 - accuracy: 0.7752 - val_loss: 2.6604 - val_accuracy: 0.4982
# Epoch 90/100
# 2/2 [==============================] - 0s 68ms/step - loss: 0.7921 - accuracy: 0.7727 - val_loss: 2.6413 - val_accuracy: 0.4956
# Epoch 91/100
# 2/2 [==============================] - 0s 63ms/step - loss: 0.7940 - accuracy: 0.7737 - val_loss: 2.6369 - val_accuracy: 0.4996
# Epoch 92/100
# 2/2 [==============================] - 0s 69ms/step - loss: 0.7800 - accuracy: 0.7745 - val_loss: 2.6095 - val_accuracy: 0.5004
# Epoch 93/100
# 2/2 [==============================] - 0s 66ms/step - loss: 0.7697 - accuracy: 0.7777 - val_loss: 2.6460 - val_accuracy: 0.4970
# Epoch 94/100
# 2/2 [==============================] - 0s 70ms/step - loss: 0.7744 - accuracy: 0.7731 - val_loss: 2.6312 - val_accuracy: 0.4976
# Epoch 95/100
# 2/2 [==============================] - 0s 71ms/step - loss: 0.7635 - accuracy: 0.7779 - val_loss: 2.6091 - val_accuracy: 0.5020
# Epoch 96/100
# 2/2 [==============================] - 0s 65ms/step - loss: 0.7436 - accuracy: 0.7841 - val_loss: 2.6059 - val_accuracy: 0.5018
# Epoch 97/100
# 2/2 [==============================] - 0s 73ms/step - loss: 0.7347 - accuracy: 0.7877 - val_loss: 2.6011 - val_accuracy: 0.5062
# Epoch 98/100
# 2/2 [==============================] - 0s 67ms/step - loss: 0.7273 - accuracy: 0.7899 - val_loss: 2.5947 - val_accuracy: 0.5040
# Epoch 99/100
# 2/2 [==============================] - 0s 62ms/step - loss: 0.7159 - accuracy: 0.7905 - val_loss: 2.5814 - val_accuracy: 0.5046
# Epoch 100/100
# 2/2 [==============================] - 0s 73ms/step - loss: 0.7192 - accuracy: 0.7896 - val_loss: 2.5817 - val_accuracy: 0.5022

# %% [markdown]
# ## 1.c)

# %%
h=train.history
plt.figure(figsize=(10,5))
plt.plot(h['loss'])
plt.plot(h['val_loss'])
plt.plot(h['accuracy'])
plt.plot(h['val_accuracy'])
plt.grid(True)
plt.axis([0,100,0,5.25])
# Out:
# (0.0, 100.0, 0.0, 5.25)

# %% [markdown]
# ## 1.d)

# %%
Y2e=mlp.predict(X2)
y2e=np.argmax(Y2e,axis=1)
print(confusion_matrix(y2,y2e))
print('Score:',np.sum(y2==y2e)/y2.shape[0]*100)
print('Number of erros:', np.sum(y2!=y2e))
# Out:
# [[299  23   3  11  39  31   4  20  33  37]
#  [  7 249  39   9  47  15  46   5  50  33]
#  [ 10  58 199  20  34  30  39  30  31  49]
#  [  9  26  20 285  16  29  32  21  42  20]
#  [ 44  43  35  10 254  16  35  19  11  33]
#  [  3  42  72  12  20 261  41   6  21  22]
#  [ 12  38  51  15  41  13 268  20  30  12]
#  [ 26  29  42  22  63  15  28 193  38  44]
#  [ 12  30  29  28  19  24  47  15 256  40]
#  [ 15  44  53  10  52  11  18  24  26 247]]
# Score: 50.22
# Number of erros: 2489

# %% [markdown]
# <hr style="border:2px solid black"> </hr>

# %% [markdown]
# # Question 2
# ## Consider a MLP network with the same architecture of the MLP from the previous question. The only difference being the input layer.
# ### a) Pre-process the data using the function  $\texttt{PCA(withen=True)}$. Train this function with the training data and apply the transformation to the training and test sets. Preseve only the first 250 principal componentes of the data. Use the pre-processed data in the following items.
# ### b)  Build this network, and compile it with the loss and the optimizer used in the previous question.  Train the network for 100 epochs with a batch-size of 5000. Use the kMNIST training set and include the test data as the validation set during training.
# ### c) On the same figure, plot the curve of the losses and the accuracies for the training and validation sets during the training process.  Comment the results. Also print the total number of errors and the confusion matrix for the test dataset.

# %% [markdown]
# ## 2.a)

# %%
from sklearn.decomposition import PCA

D=pickle.load(open('kMNISTsmall.p','rb'))
X1=D.X1*1.
X2=D.X2*1.
y1=D.y1
y2=D.y2

X1=X1.reshape((10000,784))*1.
X2=X2.reshape((5000,784))*1.
Y1=keras.utils.to_categorical(y1)
Y2=keras.utils.to_categorical(y2)
print(X1.shape,X2.shape,Y1.shape,Y2.shape)

nCP=250
pca=PCA(n_components=nCP,whiten=True).fit(X1)
X1p=pca.transform(X1)
X2p=pca.transform(X2)

print(X1p.shape)
# Out:
# (10000, 784) (5000, 784) (10000, 10) (5000, 10)
# (10000, 250)

# %%
X2p.shape
# Out:
# (5000, 150)

# %% [markdown]
# ## 2.b)

# %%
#build the MLP
mlp=keras.Sequential()
mlp.add(keras.layers.Flatten(input_shape=(nCP,)))
mlp.add(keras.layers.Dense(50,activation='relu'))
mlp.add(keras.layers.Dense(50,activation='relu'))
mlp.add(keras.layers.Dense(50,activation='relu'))
mlp.add(keras.layers.Dense(10,activation='softmax'))
print(mlp.summary())

#compile the network
mlp.compile(optimizer='nadam',loss='categorical_crossentropy',metrics=['accuracy'])
train=mlp.fit(X1p,Y1,epochs=100,batch_size=5000,validation_data=(X2p,Y2))
# Out:
# Model: "sequential_19"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_19 (Flatten)         (None, 250)               0
# _________________________________________________________________
# dense_76 (Dense)             (None, 50)                12550
# _________________________________________________________________
# dense_77 (Dense)             (None, 50)                2550
# _________________________________________________________________
# dense_78 (Dense)             (None, 50)                2550
# _________________________________________________________________
# dense_79 (Dense)             (None, 10)                510
# =================================================================
# Total params: 18,160
# Trainable params: 18,160
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/100
# 2/2 [==============================] - 1s 179ms/step - loss: 2.5168 - accuracy: 0.0875 - val_loss: 2.4743 - val_accuracy: 0.0908
# Epoch 2/100
# 2/2 [==============================] - 0s 77ms/step - loss: 2.4464 - accuracy: 0.0936 - val_loss: 2.4304 - val_accuracy: 0.0912
# Epoch 3/100
# 2/2 [==============================] - 0s 67ms/step - loss: 2.4013 - accuracy: 0.0978 - val_loss: 2.3957 - val_accuracy: 0.0984
# Epoch 4/100
# 2/2 [==============================] - 0s 50ms/step - loss: 2.3644 - accuracy: 0.1035 - val_loss: 2.3677 - val_accuracy: 0.1048
# Epoch 5/100
# 2/2 [==============================] - 0s 51ms/step - loss: 2.3328 - accuracy: 0.1121 - val_loss: 2.3448 - val_accuracy: 0.1080
# Epoch 6/100
# 2/2 [==============================] - 0s 43ms/step - loss: 2.3054 - accuracy: 0.1238 - val_loss: 2.3257 - val_accuracy: 0.1148
# Epoch 7/100
# 2/2 [==============================] - 0s 48ms/step - loss: 2.2808 - accuracy: 0.1366 - val_loss: 2.3097 - val_accuracy: 0.1232
# Epoch 8/100
# 2/2 [==============================] - 0s 51ms/step - loss: 2.2581 - accuracy: 0.1508 - val_loss: 2.2955 - val_accuracy: 0.1300
# Epoch 9/100
# 2/2 [==============================] - 0s 47ms/step - loss: 2.2363 - accuracy: 0.1674 - val_loss: 2.2825 - val_accuracy: 0.1412
# Epoch 10/100
# 2/2 [==============================] - 0s 67ms/step - loss: 2.2152 - accuracy: 0.1883 - val_loss: 2.2702 - val_accuracy: 0.1520
# Epoch 11/100
# 2/2 [==============================] - 0s 55ms/step - loss: 2.1936 - accuracy: 0.2094 - val_loss: 2.2581 - val_accuracy: 0.1612
100
# 2/2 [==============================] - 0s 45ms/step - loss: 0.0988 - accuracy: 0.9880 - val_loss: 1.8163 - val_accuracy: 0.6210
# Epoch 94/100
# 2/2 [==============================] - 0s 59ms/step - loss: 0.0956 - accuracy: 0.9889 - val_loss: 1.8330 - val_accuracy: 0.6204
# Epoch 95/100
# 2/2 [==============================] - 0s 42ms/step - loss: 0.0923 - accuracy: 0.9894 - val_loss: 1.8513 - val_accuracy: 0.6214
# Epoch 96/100
# 2/2 [==============================] - 0s 42ms/step - loss: 0.0886 - accuracy: 0.9908 - val_loss: 1.8557 - val_accuracy: 0.6196
# Epoch 97/100
# 2/2 [==============================] - 0s 45ms/step - loss: 0.0848 - accuracy: 0.9919 - val_loss: 1.8656 - val_accuracy: 0.6202
# Epoch 98/100
# 2/2 [==============================] - 0s 46ms/step - loss: 0.0816 - accuracy: 0.9919 - val_loss: 1.8870 - val_accuracy: 0.6218
# Epoch 99/100
# 2/2 [==============================] - 0s 45ms/step - loss: 0.0787 - accuracy: 0.9926 - val_loss: 1.8953 - val_accuracy: 0.6216
# Epoch 100/100
# 2/2 [==============================] - 0s 51ms/step - loss: 0.0759 - accuracy: 0.9932 - val_loss: 1.9079 - val_accuracy: 0.6220

# %% [markdown]
# ## 2.c)

# %%
h=train.history
plt.figure(figsize=(10,5))
plt.plot(h['loss'])
plt.plot(h['val_loss'])
plt.plot(h['accuracy'])
plt.plot(h['val_accuracy'])
plt.grid(True)
plt.axis([0,100,0,2])

Y2e=mlp.predict(X2p)
y2e=np.argmax(Y2e,axis=1)
print(confusion_matrix(y2,y2e))
print('Score:',np.sum(y2==y2e)/y2.shape[0]*100)
print('Number of erros:', np.sum(y2!=y2e))
# Out:
# [[319  10  15  13  42  28   2  21  32  18]
#  [  7 324  27  17  32   5  36  12  26  14]
#  [  5  23 275  26  36  10  37  25  34  29]
#  [  6  18  27 354   8  17  15  13  32  10]
#  [ 30  35  28  21 302   7  19  15  14  29]
#  [ 10  22  57  19  10 310  30  10  27   5]
#  [  6  29  41  13  18   4 343  17  21   8]
#  [ 29  24   9  18  54   8  36 254  35  33]
#  [ 11  25  46  27  12  15  22   7 323  12]
#  [ 12  48  19  12  41   8  15  17  22 306]]
# Score: 62.2
# Number of erros: 1890

# %% [markdown]
# <hr style="border:2px solid black"> </hr>

# %% [markdown]
# # Question 3
# ## Consider a MLP network an architecture of your choice, using any type of layers, activation functions or other parameters  that might imporve the results. You can also perform any type of pre-processing of the $\texttt{kMNISTsmall}$ data if it helps improve performance. Train and test this new network. Make sure the test results are better than in the previous 2 questions.

# %%
#load data
D=pickle.load(open('kMNISTsmall.p','rb'))
X1=D.X1*1.
X2=D.X2*1.
y1=D.y1
y2=D.y2

X1=X1.reshape((10000,784))/255.
X2=X2.reshape((5000,784))/255.
#take out some dims
#s=np.std(X1,axis=0)
#idx=s>.2
#X1=X1[:,idx]
#X2=X2[:,idx]
Y1=keras.utils.to_categorical(y1)
Y2=keras.utils.to_categorical(y2)


mlp=keras.Sequential()
mlp.add(keras.layers.Dense(50,activation='relu',input_shape=(X1.shape[1],)))
mlp.add(keras.layers.Dropout(.3))
mlp.add(keras.layers.Dense(50,activation='relu'))
mlp.add(keras.layers.Dropout(.3))
mlp.add(keras.layers.Dense(50,activation='relu'))
mlp.add(keras.layers.Dense(10,activation='softmax'))
#compile the network
mlp.compile(optimizer='nadam',loss='categorical_crossentropy',metrics=['accuracy'])

# %%
200
# 2/2 [==============================] - 0s 64ms/step - loss: 0.2584 - accuracy: 0.9186 - val_loss: 0.8222 - val_accuracy: 0.7788

# %%
h=train.history
plt.figure(figsize=(10,5))
plt.plot(h['loss'])
plt.plot(h['val_loss'])
plt.plot(h['accuracy'])
plt.plot(h['val_accuracy'])
plt.grid(True)
plt.axis([0,200,0,1.5])

Y2e=mlp.predict(X2)
y2e=np.argmax(Y2e,axis=1)
print(confusion_matrix(y2,y2e))
print('Score:',np.sum(y2==y2e)/y2.shape[0]*100)
print('Number of erros:', np.sum(y2!=y2e))
# Out:
# [[420   5   0   5  15  14   1  16  20   4]
#  [  6 387  18   4  16   4  25   1  24  15]
#  [  4  16 366  14  16   8  20  14  25  17]
#  [  3   6  37 418   3   7   7   3  13   3]
#  [ 37  25  11  11 359   6   6  11  13  21]
#  [  2  18  44   6   9 378  10   1  27   5]
#  [  1  18  25   4  26   0 408   8   7   3]
#  [ 17  13  14   4  32   3  24 334  27  32]
#  [ 10  13   8  17   4   3  12   1 429   3]
#  [  3  16  19   0  24   4  12  13  14 395]]
# Score: 77.88000000000001
# Number of erros: 1106

# %%
from keras.callbacks import EarlyStopping

# Definir um range de valores para os hiperparâmetros
learning_rates = [0.001, 0.01, 0.1]
batch_sizes = [32, 64, 128]
dropouts = [0.2, 0.3, 0.4]
num_layers = [1, 2, 3]

best_accuracy = 0

# Loop pelos hiperparâmetros
for lr in learning_rates:
    for batch_size in batch_sizes:
        for dropout in dropouts:
            for layers in num_layers:
                
                # Definir a arquitetura da rede
                mlp = keras.Sequential()
                mlp.add(keras.layers.Dense(200, activation='relu', input_shape=(X1.shape[1],)))
                mlp.add(keras.layers.Dropout(dropout))
                
                # Adicionar camadas intermediárias
                for i in range(layers):
                    mlp.add(keras.layers.Dense(200, activation='relu'))
                    mlp.add(keras.layers.Dropout(dropout))
                
                mlp.add(keras.layers.Dense(100, activation='relu'))
                mlp.add(keras.layers.Dense(10, activation='softmax'))
                
                # Compilar a rede com os hiperparâmetros escolhidos
                mlp.compile(optimizer=keras.optimizers.Nadam(lr=lr),
                            loss='categorical_crossentropy',
                            metrics=['accuracy'])
                
                # Treinar a rede
                history = mlp.fit(X1, Y1, epochs=150, batch_size=batch_size,
                                  validation_data=(X2, Y2),
                                  callbacks=[EarlyStopping(patience=5)],
                                  verbose=0)
                
                # Obter a acurácia no conjunto de validação
                accuracy = history.history['val_accuracy'][-1]
                
                # Verificar se a acurácia é a melhor até agora
                if accuracy > best_accuracy:
                    best_lr = lr
                    best_batch_size = batch_size
                    best_dropout = dropout
                    best_layers = layers
                    best_accuracy = accuracy
                    
# Imprimir os melhores hiperparâmetros encontrados
print(f"Best learning rate: {best_lr}")
print(f"Best batch size: {best_batch_size}")
print(f"Best dropout: {best_dropout}")
print(f"Best number of layers: {best_layers}")
print(f"Best accuracy: {best_accuracy}")
